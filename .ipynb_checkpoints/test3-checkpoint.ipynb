# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import model_selection, preprocessing, metrics
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from datetime import datetime
import lightgbm
import seaborn as sns
import xgboost

from sklearn import neural_network
from scipy.stats import hmean

# %%
df = pd.read_csv("../wns-wizard-av/Train/train.csv")
df.head(10)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
# 5  3416a75f4cea9109507cacd8e2f2aefc  2018-11-15 00:03:00    67352       409
# 6  f457c545a9ded88f18ecee47145a72c0  2018-11-15 00:03:00    64356       190
# 7  72b32a1f754ba1c09b3695e0cb6cde7f  2018-11-15 00:04:00    27329       481
# 8  fc490ca45c00b1249bbe3554a4fdf6fb  2018-11-15 00:05:00    83318       386
# 9  d2ddea18f00665ce8623e36bd4e3c7c5  2018-11-15 00:05:00    70206       190
#
#      os_version  is_4G  is_click
# 0           old      0         0
# 1        latest      1         1
# ...

# %%
df_v = pd.read_csv("../wns-wizard-av/Train/view_log.csv")
df_v.sample(10)
# Out:
#                  server_time device_type  session_id  user_id  item_id
# 123367   2018-10-17 18:09:00     android      980534    78151    73386
# 1295639  2018-11-10 06:17:00     android      319276    79543    90236
# 2858804  2018-12-07 21:19:00     android      599303    60962    55568
# 691198   2018-10-29 15:03:00     android      151594    89837     8091
# 213156   2018-10-19 14:25:00     android      464463    33091    30048
# 3000583  2018-12-10 11:00:00     android      826478    76082    67649
# 1444634  2018-11-12 20:26:00     android      817127    88243    30050
# 2907078  2018-12-08 19:55:00     android      888213    14395    98128
# 119121   2018-10-17 16:36:00     android      638599     2591    30758
# 1841216  2018-11-19 13:52:00     android      878379    43527    37894

# %%
df_i = pd.read_csv("../wns-wizard-av/Train/item_data.csv")
df_i.sample(10)
# Out:
#         item_id  item_price  category_1  category_2  category_3  product_type
# 67218     13922         633           9          37         162          5062
# 124177    96925       26688           1          42         220          1617
# 67493     84926       38336           1          42         157          4540
# 94408     42848       25036           9           3         312          9174
# 78122    129386        1209          13          78         221          2466
# 4786      89540        2809          17           8         159          8607
# 119121    49307         859          11          51          15          3550
# 93076     43424        2496           9          66         193          6117
# 102400    20169        2240           7          31         271           534
# 14526     73516        1728          15           0         214          9213

# %%
print(df.info(), "\n\n")
print(df_v.info(), "\n\n")
print(df_i.info(), "\n\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237609 entries, 0 to 237608
# Data columns (total 7 columns):
# impression_id      237609 non-null object
# impression_time    237609 non-null object
# user_id            237609 non-null int64
# app_code           237609 non-null int64
# os_version         237609 non-null object
# is_4G              237609 non-null int64
# is_click           237609 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 12.7+ MB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3118622 entries, 0 to 3118621
# Data columns (total 5 columns):
# server_time    object
# device_type    object
# session_id     int64
# user_id        int64
# item_id        int64
# dtypes: int64(3), object(2)
# memory usage: 119.0+ MB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132761 entries, 0 to 132760
# Data columns (total 6 columns):
# item_id         132761 non-null int64
# item_price      132761 non-null int64
# ...

# %%
# Changing impression time and server time from object to datetime
df["impression_time"] = pd.to_datetime(df["impression_time"], format="%Y-%m-%d %H:%M:%S")
df_v["server_time"] = pd.to_datetime(df_v["server_time"], format="%Y-%m-%d %H:%M:%S")

# %%
# Describe advertisement dataset
print(df.describe())
# Out:
#              user_id       app_code          is_4G       is_click
# count  237609.000000  237609.000000  237609.000000  237609.000000
# mean    46454.526828     249.099971       0.361312       0.045714
# std     26802.726666     135.213609       0.480382       0.208864
# min         0.000000       0.000000       0.000000       0.000000
# 25%     23197.000000     163.000000       0.000000       0.000000
# 50%     46597.000000     213.000000       0.000000       0.000000
# 75%     69684.000000     385.000000       1.000000       0.000000
# max     92586.000000     522.000000       1.000000       1.000000

# %%
print(df["os_version"].describe(), "\n")
print(df["is_click"].describe())
# Out:
# count     237608
# unique         3
# top       latest
# freq      129216
# Name: os_version, dtype: object
#
# count    237608.000000
# mean          0.045714
# std           0.208864
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: is_click, dtype: float64

# %%
a = sns.countplot(x = df["os_version"])
a.tick_params(labelsize=20)

# %%
b = sns.countplot(df["is_click"])
b.set_xlabel("is click",fontsize=30)
b.tick_params(labelsize=20)

# %% [markdown]
# ### Hypothesis
# * user_id = 0 is an error
# * Imbalance dataset that clicked with not clicked

# %%
df[df["user_id"] == 0]
# Out:
#                            impression_id     impression_time  user_id  \
# 104312  5f98c2c31a8006e510448c02ec74d50f 2018-11-26 23:30:00        0
#
#         app_code os_version  is_4G  is_click
# 104312       207        old      0         0

# %%
df[df["user_id"] == 2]
# Out:
#                           impression_id     impression_time  user_id  \
# 24562  010ed37e44e2fdc175b4c5c6c930805a 2018-11-20 20:53:00        2
# 49515  2b12c0d47f5821a5adb3bfd973d0f708 2018-11-19 20:49:00        2
# 54202  f85e4bf0e34f3ee66add56229845e4db 2018-11-20 20:29:00        2
# 78666  577c63f9937fa0e8d4650ddf1510a03f 2018-11-21 21:47:00        2
#
#        app_code    os_version  is_4G  is_click
# 24562       190  intermediate      0         0
# 49515       190  intermediate      0         0
# 54202       190  intermediate      0         0
# 78666       190  intermediate      0         0

# %%
# Drop the zero userId for it is only 1 row
df = df[df["user_id"] != 0]
df.describe()
# Out:
#              user_id       app_code          is_4G       is_click
# count  237608.000000  237608.000000  237608.000000  237608.000000
# mean    46454.722337     249.100148       0.361314       0.045714
# std     26802.613637     135.213866       0.480382       0.208864
# min         2.000000       0.000000       0.000000       0.000000
# 25%     23197.000000     163.000000       0.000000       0.000000
# 50%     46597.000000     213.000000       0.000000       0.000000
# 75%     69684.000000     385.000000       1.000000       0.000000
# max     92586.000000     522.000000       1.000000       1.000000

# %%
print(df_v["device_type"].describe())
sns.countplot(df_v["device_type"])
# Out:
# count     3118622
# unique          3
# top       android
# freq      3117737
# Name: device_type, dtype: object

# %%
print(df[df["is_click"] == 1].shape)
df[df["app_code"] == 0]
# Out:
# (10862, 7)
#                            impression_id     impression_time  user_id  \
# 6050    961f1e759d4e9cca6754b1477b3b491a 2018-11-15 19:23:00    80969
# 9696    54f9eb2f4102265b326bcf235660e9f0 2018-11-18 14:56:00     7216
# 11756   66d65498077ac583806d1c8b684b946e 2018-11-16 20:18:00    18691
# 12341   c9108dde6dd7b4e071129d2f9100fa55 2018-11-17 19:28:00    36369
# 12785   c644332952f476c37daa950b502c850e 2018-11-17 18:35:00    27696
# 12894   b6d7a951171944f9a12d2812cd058251 2018-11-17 22:25:00    18691
# 13740   e62e4e249110f293347233352a4edf81 2018-11-18 19:49:00    18691
# 18078   838aac83e00e8c5ca0f839c96d6cb3be 2018-11-15 14:58:00    27696
# 21944   30de24287a6d8f07b37c716ad51623a7 2018-11-15 15:39:00    27696
# 24584   ec9b606d4c0673aa256696c06cc9e785 2018-11-16 19:33:00    18691
# 27991   cddaa6e1ad5ba4c70c6c05db38099fa0 2018-11-15 22:39:00    80969
# 31423   eb6fcbbecd73338c6fbfac452fb96b7c 2018-11-20 22:26:00     3342
# ...

# %% [markdown]
# #### Dataset about advertisement quality
# * There is 10,862 user that click from 237,609 or only about 0.04571 imbalance at this attribute
# * There is outlier in user ID and appcode
# * There is no missing value

# %%
# Describe view log dataset
df_v.describe()
# Out:
#          session_id       user_id       item_id
# count  3.118622e+06  3.118622e+06  3.118622e+06
# mean   5.451129e+05  4.617972e+04  6.605151e+04
# std    3.147682e+05  2.672813e+04  3.826626e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.726422e+05  2.312200e+04  3.321900e+04
# 50%    5.454915e+05  4.617700e+04  6.747900e+04
# 75%    8.175090e+05  6.933900e+04  9.927000e+04
# max    1.089677e+06  9.258600e+04  1.328650e+05

# %% [markdown]
# ### Hypothesis
# * session_id = 0 is error
# * user_id = 0 is error
# * item_id = 0 is error

# %%
df_v[df_v["session_id"] == 0]
# Out:
#                 server_time device_type  session_id  user_id  item_id
# 1465427 2018-11-13 05:01:00     android           0    19007    69585
# 1465441 2018-11-13 05:02:00     android           0    19007    81804

# %%
# Drop session_id = 0, it will be probably error in entry
df_v = df_v[df_v["session_id"] != 0]

# %%
df_v[df_v["user_id"] == 19007]
# Out:
#                 server_time device_type  session_id  user_id  item_id
# 77614   2018-10-16 20:27:00     android      560635    19007    61487
# 77702   2018-10-16 20:28:00     android      560635    19007    61487
# 77753   2018-10-16 20:29:00     android      560635    19007    23668
# 77805   2018-10-16 20:30:00     android      560635    19007    61487
# 77829   2018-10-16 20:30:00     android      560635    19007    61974
# 457348  2018-10-24 15:15:00     android      258052    19007    92340
# 468884  2018-10-24 19:45:00     android       34199    19007    88425
# 517971  2018-10-25 20:26:00     android      827472    19007   119516
# 714600  2018-10-29 22:39:00     android      108744    19007   119516
# 714614  2018-10-29 22:39:00     android      108744    19007   119516
# 714636  2018-10-29 22:40:00     android      108744    19007   119516
# 715356  2018-10-29 22:54:00     android      108744    19007   119516
# ...

# %%
df_v[df_v["item_id"] == 0]
# Out:
#                 server_time device_type  session_id  user_id  item_id
# 363076  2018-10-22 19:17:00     android       95432    40223        0
# 1465146 2018-11-13 04:35:00     android     1071604    22297        0

# %% [markdown]
# #### Dataset about view log quality
# * There is no missing value
# * Item id = 0 is outlier
# * imbalance of android and iphone user

# %% [markdown]
# ## Overall Data Quality
# * There are imbalance
#     * Android, Iphone, and web user
#     * Clicked ad and not clicked ad
# * There are outlier
#     * itemid in view log
#     * userId and app code

# %% [markdown]
# ## Data Understanding

# %%
# Out:
#           server_time device_type  session_id  user_id  item_id  visit_number
# 0 2018-10-18 14:27:00     android      268465        0    44459             1
# 1 2018-10-18 14:27:00     android      268465        0    44459             2
# 2 2018-10-18 14:43:00     android      268465        0    44459             3
# 3 2018-10-18 14:46:00     android      268465        0    44459             4
# 4 2018-10-18 14:46:00     android      268465        0    44459             5
# 5 2018-10-18 14:47:00     android      268465        0    44459             6
# 6 2018-10-22 09:48:00     android      295495        0    40228             7
# 7 2018-10-26 09:07:00     android      675965        0    58320             8
# 8 2018-10-26 09:08:00     android      675965        0   129641             9
# 9 2018-11-06 14:46:00     android      956652        0    40228            10
